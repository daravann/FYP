# %%
# Basic imports
import pycba as cba  # The main package
import numpy as np  # For arrays
import matplotlib.pyplot as plt  # For plotting
from IPython import display  # For images in this notebook

# %%
#test bridge 24m 
L = [5.217, 13.566, 5.217]
EI = 30 * 600e7 * 1e-6
R = [-1, 0, -1, 0, -1, 0 , -1, 0]
LM = [[2, 2, 500, 6.783, 0]]
#Span No. | Load Type | Load Value | Distance a | Load Cover c

# %%
beam_analysis = cba.BeamAnalysis(L, EI, R, LM)
beam_analysis.analyze()
beam_analysis.plot_results()

# %%
beam_analysis.beam_results.R
# Out:
# array([-129.35740078,  379.35740078,  379.35740078, -129.35740078])

# %%
beam_analysis.beam_results.vRes[1].M.max()
# Out:
# 1020.8924401548932

# %%
# axle_spacings = np.array([6, 1.2])
# axle_weights = np.array([6, 12, 12]) * 9.81  # t to kN

# bridge_analysis = cba.BridgeAnalysis()
# bridge = bridge_analysis.add_bridge(L, EI, R)
# vehicle = bridge_analysis.add_vehicle(axle_spacings, axle_weights)

# bridge_analysis.static_vehicle(30.0, True);

# %%
axle_spacings = np.array([2])
axle_weights = np.array([6, 6]) * 9.81  # t to kN

bridge_analysis = cba.BridgeAnalysis()
bridge = bridge_analysis.add_bridge(L, EI, R)
vehicle = bridge_analysis.add_vehicle(axle_spacings, axle_weights)

bridge_analysis.static_vehicle(15.0, True);

# %%
bridge_analysis.run_vehicle(0.5, plot_env=True, plot_all=False);

# %%
# #influnce line
# beam_string = "E5R14R5E"
# (L, EI, R, eType) = cba.parse_beam_string(beam_string)
# ils = cba.InfluenceLines(L, EI, R, eType)
# ils.create_ils(step=0.05)
# ils.plot_il(0.0, "R")

# %%
# #moving load cae
# L = [5,14,5]
# EI = 30 * 600e7 * 1e-6
# R = [-1, 0, -1, 0, -1, 0 , -1, 0]

# axle_spacings = np.array([2, 2])
# axle_weights = np.array([2, 12, 12]) * 9.81  # t to kN

# bridge_analysis = cba.BridgeAnalysis()
# bridge = bridge_analysis.add_bridge(L, EI, R)
# vehicle = bridge_analysis.add_vehicle(axle_spacings, axle_weights)

# bridge_analysis.static_vehicle(12.0, True);

# %%
# bridge_analysis.run_vehicle(0.5, plot_env=True, plot_all=False);

# %%
L = [25.22,33.56,25.22]
EI = 30 * 600e7 * 1e-6
R = [-1, 0, -1, 0, -1, 0 , -1, 0]
LM = [[2, 2, 800, 16.78, 0]]
#Span No. | Load Type | Load Value | Distance a | Load Cover c

# %%
beam_analysis = cba.BeamAnalysis(L, EI, R, LM)
beam_analysis.analyze()
beam_analysis.plot_results()

# %%
beam_analysis.beam_results.R

# %%
beam_analysis.beam_results.vRes[1].M.max()

# %%
beam_analysis.beam_results.vRes[1].M

# %%
L = [25,34,25]
EI = 30 * 600e7 * 1e-6
R = [-1, 0, -1, 0, -1, 0 , -1, 0]
LM = [[2, 2, 800, 5, 0],[2, 2, 800, 25, 0]]
#Span No. | Load Type | Load Value | Distance a | Load Cover c

beam_analysis = cba.BeamAnalysis(L, EI, R, LM)
beam_analysis.analyze()
beam_analysis.plot_results()
beam_analysis.beam_results.R
beam_analysis.beam_results.vRes[1].M.max()

# %%
beam_analysis.beam_results.vRes[1].M
